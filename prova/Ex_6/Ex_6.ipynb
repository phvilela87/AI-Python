# %% [markdown]
# # Exercício 6

# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio
from sklearn.cluster import KMeans
from sklearn.datasets import load_sample_image
from sklearn.utils import shuffle
from PIL import Image

# %%
def recreate_image(codebook, labels, w, h):
    """Recreate the (compressed) image from the code book & labels"""
    d = codebook.shape[1]
    image = np.zeros((w, h, d))
    label_idx = 0
    for i in range(w):
        for j in range(h):
            image[i][j] = codebook[labels[label_idx]]
            label_idx += 1
    return image

# %%
n_colors = 2

# Load bird image
bird_img = imageio.imread('img2.jpg')

# Convert to floats instead of the default 8 bits integer coding. Dividing by
# 255 is important so that plt.imshow behaves works well on float data (need to
# be in the range [0-1])
bird_img = np.array(bird_img, dtype=np.float64) / 255

# Load Image and transform to a 2D numpy array.
w, h, d = original_shape = tuple(bird_img.shape)
assert d == 3
image_array = np.reshape(bird_img, (w * h, d))

image_array_sample = shuffle(image_array, random_state=0)[:1000]
kmeans = KMeans(n_clusters=n_colors, random_state=0).fit(image_array_sample)

# Get labels for all points
labels = kmeans.predict(image_array)

# %%
# Display image with 2 colours
plt.figure(1)
plt.clf()
plt.axis('off')
plt.title('Quantized image (2 colors, K-Means)')
plt.imshow(recreate_image(kmeans.cluster_centers_, labels, w, h))

# %%
n_colors = 4

# Load bird image
bird_img = imageio.imread('img2.jpg')

# Convert to floats instead of the default 8 bits integer coding. Dividing by
# 255 is important so that plt.imshow behaves works well on float data (need to
# be in the range [0-1])
bird_img = np.array(bird_img, dtype=np.float64) / 255

# Load Image and transform to a 2D numpy array.
w, h, d = original_shape = tuple(bird_img.shape)
assert d == 3
image_array = np.reshape(bird_img, (w * h, d))

image_array_sample = shuffle(image_array, random_state=0)[:1000]
kmeans = KMeans(n_clusters=n_colors, random_state=0).fit(image_array_sample)

# Get labels for all points
labels = kmeans.predict(image_array)

# %%
# Display image with 4 colours
plt.figure(2)
plt.clf()
plt.axis('off')
plt.title('Quantized image (4 colors, K-Means)')
plt.imshow(recreate_image(kmeans.cluster_centers_, labels, w, h))

# %%
n_colors = 8

# Load bird image
bird_img = imageio.imread('img2.jpg')

# Convert to floats instead of the default 8 bits integer coding. Dividing by
# 255 is important so that plt.imshow behaves works well on float data (need to
# be in the range [0-1])
bird_img = np.array(bird_img, dtype=np.float64) / 255

# Load Image and transform to a 2D numpy array.
w, h, d = original_shape = tuple(bird_img.shape)
assert d == 3
image_array = np.reshape(bird_img, (w * h, d))

image_array_sample = shuffle(image_array, random_state=0)[:1000]
kmeans = KMeans(n_clusters=n_colors, random_state=0).fit(image_array_sample)

# Get labels for all points
labels = kmeans.predict(image_array)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-f584ba050c57> in <module>
#       3 # Load bird image
#       4 bird_img = imageio.imread('img2.jpg')
# ----> 5 width, height = bird_img.size
#       6
#       7 resolution = width * height
#
# TypeError: cannot unpack non-iterable int object

# %%
# Display image with 8 colours
plt.figure(3)
plt.clf()
plt.axis('off')
plt.title('Quantized image (8 colors, K-Means)')
plt.imshow(recreate_image(kmeans.cluster_centers_, labels, w, h))

# %%
n_colors = 16

# Load bird image
bird_img = imageio.imread('img2.jpg')

# Convert to floats instead of the default 8 bits integer coding. Dividing by
# 255 is important so that plt.imshow behaves works well on float data (need to
# be in the range [0-1])
bird_img = np.array(bird_img, dtype=np.float64) / 255

# Load Image and transform to a 2D numpy array.
w, h, d = original_shape = tuple(bird_img.shape)
assert d == 3
image_array = np.reshape(bird_img, (w * h, d))

image_array_sample = shuffle(image_array, random_state=0)[:1000]
kmeans = KMeans(n_clusters=n_colors, random_state=0).fit(image_array_sample)

# Get labels for all points
labels = kmeans.predict(image_array)

# %%
# Display image with 16 colours
plt.figure(4)
plt.clf()
plt.axis('off')
plt.title('Quantized image (16 colors, K-Means)')
plt.imshow(recreate_image(kmeans.cluster_centers_, labels, w, h))

# %%
# # Load original bird image
# bird_img = imageio.imread('img2.jpg')

# # Convert to floats instead of the default 8 bits integer coding. Dividing by
# # 255 is important so that plt.imshow behaves works well on float data (need to
# # be in the range [0-1])
# bird_img = np.array(bird_img, dtype=np.float64) / 255

# # Load Image and transform to a 2D numpy array.
# w, h, d = original_shape = tuple(bird_img.shape)
# assert d == 3
# image_array = np.reshape(bird_img, (w * h, d))

# %%
# # Display original image
# plt.figure(5)
# plt.clf()
# plt.axis('off')
# plt.title('Original image)')
# plt.imshow(bird_img)

# %% [markdown]
# ## Resposta

# %%
im = Image.open('img2.jpg') 

width, height = im.size

resolution = width * height

print("The image resolution is: ", width, " x ", height)
print("The resolution is: ", resolution)
# Out:
# The image resolution is:  500  x  400
# The resolution is:  200000

# %% [markdown]
# ### Para calcular o tamanho da imagem, basta seguir a seguinte formula:
#
# image size = (resolution * bit depth)/8 Bytes
# resolution = width * height  pixel/inch
#
# para representarmos 2 cores é neessário 1 bit
# para representarmos 4 cores são neessários 2 bits
# para representarmos 8 cores são neessários 3 bits
# para representarmos 16 cores são neessários 4 bits
#
# Tamanho da imagem 1
# image size = (500 * 400 * 1) / 8 = ~24kBytes
#
# Tamanho da imagem 2
# image size = (500 * 400 * 2) / 8 = ~48kBytes
#
# Tamanho da imagem 3
# image size = (500 * 400 * 3) / 8 = ~73kBytes
#
# Tamanho da imagem 4
# image size = (500 * 400 * 4) / 8 = ~97kBytes
